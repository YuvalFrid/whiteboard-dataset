# %%
import numpy as np 
import matplotlib.pyplot as plt 
from adjustText import adjust_text

from PIL import Image
from pdb import set_trace as st 
import random
import json
import os 
from tqdm import tqdm
import string
from src.Aux import * 
from src.Triangles import Triangle
from src.Illustrate import * 
from src.text_in_bbox import *

# %%
emnist_loc = "/home/yfrid/Desktop/stem-whiteboard/dataset/mnist/EMNIST/raw/"
emnist_images = read_idx_ubyte(emnist_loc+"emnist-byclass-train-images-idx3-ubyte")
emnist_labels = read_idx_ubyte(emnist_loc+"emnist-byclass-train-labels-idx1-ubyte")
emnist_chars = string.digits+string.ascii_uppercase+string.ascii_lowercase
EMNIST = EMNIST_Handler(emnist_images,emnist_labels,emnist_chars)
# Out:
# Reading image data: 697932 images of 28x28 pixels.
# Reading label data: 697932 labels.
# /home/yfrid/Desktop/GitProjects/whiteboard-dataset/src/l2q_inference.py:51: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weights_path, map_location=self.device))

# %%
lower_letters = string.ascii_lowercase
#greek_letters = ['α', 'β', 'γ', 'δ', 'θ']

def plot_geometry_improved(description):
    fig, ax = plt.subplots(figsize=(6,6),dpi = 64)
    labels = []
    handwritten =bool(random.getrandbits(1))
    # Set up the plot with some padding
    all_x = [v["x"] for v in description["vertices"]]
    all_y = [v["y"] for v in description["vertices"]]
    x_range = max(all_x) - min(all_x)
    y_range = max(all_y) - min(all_y)
    padding = max(x_range, y_range) * 0.1
    
    ax.set_xlim(min(all_x) - padding, max(all_x) + padding)
    ax.set_ylim(min(all_y) - padding, max(all_y) + padding)
####################################################### SEGMENTS
    description["index_lookup"] = {d["mark"]: i for i, d in enumerate(description["vertices"])} ## add index to each vertice for easier search
    description,segment_labels = plot_segments(description,ax,EMNIST,handwritten)
################################################### SPECIALS
    description = plot_specials(description,ax,EMNIST,handwritten)

################################################### ANGLES
    description, angle_labels = plot_angles(description,ax,EMNIST,handwritten)

    

#################################################### Text
    text = ""
    for segment in description["segments"]:
        if segment["known"] == True:
            text += f'{segment["mark"]} = {segment["length"]} {segment["unit"]}. '

    for angle in description["angles"]:
        if angle["known"] == True:
            text += f'∢{angle["mark"]} = {angle["value"]}°. '
    for question in description["questions"]:
        text += question
#################################################### VERTICES    
    labels = plot_vertices(description,ax,EMNIST,handwritten)

    for v in description["vertices"]:
        v["x"] = np.around((v["x"]-min(all_x))/(max(all_x)-min(all_x)),2)
        v["y"] = np.around((v["y"]-min(all_y))/(max(all_y)-min(all_y)),2)
        

##############################################################    
    # Combine all labels for adjustment
    all_labels = labels + segment_labels + angle_labels
    
    # Get all non-text artists (points, lines) to avoid
    avoid_objects = [artist for artist in ax.get_children() 
                    if not isinstance(artist, plt.Text)]
    
    # Fine-tune the label positioning
    adjust_text(all_labels, ax=ax,
                add_objects=avoid_objects,
                expand_points=(1.5, 1.5),    # Distance from points
                expand_text=(1.2, 1.2),     # Distance between labels
                expand_objects=(1.2, 1.2),  # Distance from lines/objects
                arrowprops=dict(arrowstyle='-', color='gray', alpha=0.5, lw=0.5),
                force_points=(0.5, 0.5),    # Force to avoid points
                force_text=(0.5, 0.5),      # Force to avoid text overlap
                force_objects=(0.3, 0.3),   # Force to avoid other objects
                lim=1000)                   # Maximum iterations
    
    ax.set_aspect('equal')
    ax.axis('off')

    plt.tight_layout()

    xs,ys = find_bbox(ax)
    buf = BytesIO()
    ax.figure.savefig(buf, format='png', bbox_inches='tight', dpi=64)
    plt.close(fig)
    buf.seek(0)
    img = Image.open(buf)
    cut_img_cv = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)
    y_pad_size,x_pad_size= 384-cut_img_cv.shape[0], 384-cut_img_cv.shape[1]
    img_cv = np.ones([384,384,3],dtype = np.int8)*255
    if xs[0] == 10:
        left_pad = x_pad_size
    else:
        left_pad = 0
    if ys[0] == 10:
        top_pad = y_pad_size
    else:
        top_pad = 0
    img_cv[top_pad:top_pad+cut_img_cv.shape[0],left_pad:left_pad+cut_img_cv.shape[1]] = cut_img_cv
    xs,ys = find_bbox(img_cv,"image")
#    xs[1]+= x_pad_size
#    ys[1]+= y_pad_size
#    text = f"AB⊥BC, ADE~ABC, DE∥AB ,and {chr(8738)}BAC=90°. prove ACD≅ACE"
    tokens = tokenize_with_equations(text)
    bbox = (xs[0], ys[0], xs[1]-xs[0], ys[1]-ys[0])  # x, y, width, height
#    print(xs)
#    print(ys)
    #plt.plot([xs[0],xs[1]],[ys[1],ys[0]])
    if handwritten:
        img_text = EMNIST.text_mat(tokens,bbox[2])
        img_text = np.repeat(np.expand_dims(img_text,2),3,axis = 2)
        img_text = np.array(np.round(255*img_text),dtype = np.int16)
        plt.imshow(img_cv,cmap='gray')
        plt.imshow(img_text,cmap='gray',extent=[bbox[0], 
        bbox[0] + bbox[2], bbox[1] + min(bbox[3],img_text.shape[0]), bbox[1]],
        vmin=0,
        vmax=1,
        alpha=1 # Transparency (0=invisible, 1=opaque)
    )
        plt.xlim(0,img_cv.shape[1])
        plt.ylim(img_cv.shape[0],0)
    else:
        img_text = render_wrapped_text(tokens,bbox[2], bbox[3])
        combined = overlay_text_on_image(img_cv, img_text, bbox)
        plt.imshow(combined)
    plt.axis('off')
    plt.subplots_adjust(left=0, right=1, bottom=0, top=1)

    return description


def convert_numpy_types(obj):
    if isinstance(obj, np.bool_):
        return bool(obj)
    elif isinstance(obj, (np.int_, np.intc, np.intp, np.int8, np.int16, np.int32, np.int64)):
        return int(obj)
    elif isinstance(obj, (np.float_, np.float16, np.float32, np.float64)):
        return float(obj)
    elif isinstance(obj, dict):
        return {k: convert_numpy_types(v) for k, v in obj.items()}
    elif isinstance(obj, (list, tuple)):
        return [convert_numpy_types(v) for v in obj]
    else:
        return obj

# %%
def save_json(description, output_dir, idx):
    os.makedirs(f"{output_dir}/labels", exist_ok=True)
    with open(f"{output_dir}/labels/{idx:06d}.json", 'w') as f:
        json.dump(description, f, indent=2)  # indent=2 for human readability
        
np.random.seed(1)#np.random.randint(100))  # For reproducible results
output_dir = "/home/yfrid/Desktop/stem-whiteboard/dataset/3V"


for idx in tqdm(range(0)):
    tri = Triangle(np.random.choice(range(5,15)), #### Random limb A 
                   np.random.choice(range(5,15)), #### Random limb B
                   rotation=np.random.randint(360),#### Random rotation
                   mirror=np.random.choice([True,False])) #### random mirroring 
    tri.third_vertice("scalene")
    tri.set_3V_question(num_questions = np.random.choice(range(1,4)))
    tri.rotate()
    new = plot_geometry_improved(tri.description)
    plt.savefig(f"{output_dir}/images/{idx:06d}.png", dpi=64,facecolor='white')
    save_json(convert_numpy_types(new), output_dir, idx)
    
    plt.close()


for idx in tqdm(range(1468,2000)):
    tri = Triangle(np.random.choice(range(5,15)), #### Random limb A 
                   np.random.choice(range(5,15)), #### Random limb B
                   rotation=np.random.randint(360),#### Random rotation
                   mirror=np.random.choice([True,False])) #### random mirroring 
    tri.third_vertice("right")
    tri.set_3V_question(num_questions = np.random.choice(range(1,4)))
    tri.rotate()
    new = plot_geometry_improved(tri.description)
    plt.savefig(f"{output_dir}/images/{idx:06d}.png", dpi=64,facecolor='white')
    save_json(convert_numpy_types(new), output_dir, idx)
    
    plt.close()
# Out:
# 0it [00:00, ?it/s]
#   0%|                                                   | 0/532 [00:00<?, ?it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   0%|▏                                          | 2/532 [00:00<02:40,  3.30it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   1%|▏                                          | 3/532 [00:00<02:44,  3.21it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   1%|▎                                          | 4/532 [00:01<02:36,  3.37it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   1%|▌                                          | 7/532 [00:02<04:07,  2.12it/s]Looks like you are using a tranform that doesn't support FancyArrowPatch, using ax.annotate instead. The arrows might strike through texts. Increasing shrinkA in arrowprops might help.
#   2%|▋                                          | 8/532 [00:04<06:10,  1.41it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   2%|▉                                         | 12/532 [00:05<03:00,  2.88it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   3%|█                                         | 14/532 [00:05<02:32,  3.41it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   3%|█▏                                        | 15/532 [00:05<02:36,  3.31it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   3%|█▎                                        | 17/532 [00:06<02:23,  3.58it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   3%|█▍                                        | 18/532 [00:06<02:27,  3.48it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   4%|█▌                                        | 19/532 [00:07<02:37,  3.26it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   4%|█▌                                        | 20/532 [00:07<02:39,  3.21it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   4%|█▋                                        | 22/532 [00:07<02:17,  3.70it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   5%|█▉                                        | 24/532 [00:08<02:09,  3.91it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   5%|██                                        | 26/532 [00:09<02:19,  3.63it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   5%|██▏                                       | 27/532 [00:09<02:24,  3.51it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   6%|██▎                                       | 30/532 [00:10<02:00,  4.17it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   6%|██▍                                       | 31/532 [00:10<02:15,  3.69it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   6%|██▌                                       | 32/532 [00:10<02:22,  3.52it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   7%|██▊                                       | 35/532 [00:11<01:57,  4.21it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   7%|██▊                                       | 36/532 [00:11<02:03,  4.03it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   7%|███                                       | 38/532 [00:12<01:56,  4.23it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   8%|███▏                                      | 40/532 [00:12<01:57,  4.20it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   8%|███▎                                      | 42/532 [00:13<02:19,  3.52it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   8%|███▍                                      | 44/532 [00:13<02:06,  3.84it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   8%|███▌                                      | 45/532 [00:14<02:14,  3.63it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   9%|███▊                                      | 48/532 [00:14<01:52,  4.30it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   9%|███▉                                      | 50/532 [00:15<01:55,  4.17it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  10%|████▏                                     | 53/532 [00:16<01:46,  4.50it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  10%|████▎                                     | 54/532 [00:16<02:07,  3.75it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  10%|████▎                                     | 55/532 [00:16<02:21,  3.38it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  11%|████▌                                     | 57/532 [00:17<02:10,  3.64it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  11%|████▋                                     | 60/532 [00:17<01:52,  4.19it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  12%|████▉                                     | 63/532 [00:18<01:55,  4.06it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  12%|█████▏                                    | 65/532 [00:19<01:54,  4.08it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  12%|█████▏                                    | 66/532 [00:19<02:08,  3.61it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  13%|█████▎                                    | 68/532 [00:20<02:00,  3.85it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  13%|█████▍                                    | 69/532 [00:20<02:06,  3.67it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  14%|█████▊                                    | 73/532 [00:22<03:19,  2.30it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  14%|█████▊                                    | 74/532 [00:22<03:07,  2.44it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  14%|██████                                    | 76/532 [00:23<02:27,  3.09it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  14%|██████                                    | 77/532 [00:23<02:31,  3.00it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  15%|██████▏                                   | 79/532 [00:24<02:09,  3.49it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  15%|██████▎                                   | 80/532 [00:24<02:14,  3.35it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  16%|██████▋                                   | 84/532 [00:25<01:41,  4.42it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  17%|██████▉                                   | 88/532 [00:26<01:38,  4.49it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  17%|███████                                   | 90/532 [00:26<01:40,  4.40it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  17%|███████▎                                  | 92/532 [00:27<01:44,  4.19it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  18%|███████▌                                  | 96/532 [00:28<01:30,  4.81it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  18%|███████▋                                  | 97/532 [00:28<01:39,  4.38it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  19%|███████▊                                  | 99/532 [00:29<01:42,  4.21it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  20%|████████                                 | 105/532 [00:30<01:23,  5.11it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  20%|████████▏                                | 106/532 [00:30<01:32,  4.59it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  20%|████████▎                                | 108/532 [00:30<01:35,  4.43it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  21%|████████▌                                | 111/532 [00:31<01:33,  4.52it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  21%|████████▋                                | 112/532 [00:32<01:48,  3.88it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  21%|████████▋                                | 113/532 [00:32<01:49,  3.81it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  22%|████████▊                                | 115/532 [00:32<02:11,  3.16it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  22%|████████▉                                | 116/532 [00:33<02:11,  3.15it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  22%|█████████                                | 118/532 [00:33<01:58,  3.48it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  22%|█████████▏                               | 119/532 [00:34<02:01,  3.41it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  23%|█████████▍                               | 123/532 [00:35<01:34,  4.35it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  23%|█████████▌                               | 124/532 [00:35<01:48,  3.78it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  23%|█████████▋                               | 125/532 [00:35<01:58,  3.45it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  24%|█████████▋                               | 126/532 [00:36<01:59,  3.39it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  24%|█████████▊                               | 127/532 [00:36<02:05,  3.23it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  24%|█████████▊                               | 128/532 [00:36<02:05,  3.23it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  25%|██████████▍                              | 135/532 [00:39<02:18,  2.86it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  26%|██████████▌                              | 137/532 [00:39<01:52,  3.50it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  26%|██████████▋                              | 138/532 [00:39<01:54,  3.43it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  26%|██████████▋                              | 139/532 [00:40<01:57,  3.35it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  27%|██████████▊                              | 141/532 [00:41<03:37,  1.80it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  27%|███████████                              | 143/532 [00:42<02:33,  2.53it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  29%|███████████▊                             | 153/532 [00:44<01:27,  4.33it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  29%|███████████▊                             | 154/532 [00:44<01:41,  3.72it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  29%|████████████                             | 156/532 [00:45<01:37,  3.86it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  30%|████████████                             | 157/532 [00:45<01:42,  3.66it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  30%|████████████▏                            | 158/532 [00:45<01:51,  3.35it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  30%|████████████▎                            | 159/532 [00:46<01:52,  3.33it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  30%|████████████▎                            | 160/532 [00:46<01:53,  3.28it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  30%|████████████▍                            | 161/532 [00:46<01:59,  3.10it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  31%|████████████▊                            | 167/532 [00:48<01:14,  4.91it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  32%|█████████████▏                           | 171/532 [00:49<01:13,  4.91it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  32%|█████████████▎                           | 172/532 [00:49<01:30,  3.99it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  33%|█████████████▍                           | 175/532 [00:50<01:20,  4.43it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  33%|█████████████▋                           | 177/532 [00:50<01:24,  4.21it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  33%|█████████████▋                           | 178/532 [00:50<01:36,  3.67it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  34%|█████████████▉                           | 181/532 [00:51<01:22,  4.24it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  34%|██████████████                           | 183/532 [00:52<01:25,  4.08it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  35%|██████████████▎                          | 186/532 [00:52<01:16,  4.52it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  36%|██████████████▌                          | 189/532 [00:53<01:15,  4.53it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  36%|██████████████▋                          | 191/532 [00:54<01:17,  4.41it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  36%|██████████████▊                          | 192/532 [00:54<01:29,  3.82it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  36%|██████████████▉                          | 194/532 [00:54<01:24,  4.02it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  37%|███████████████                          | 196/532 [00:55<01:24,  3.97it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  37%|███████████████▎                         | 198/532 [00:56<02:00,  2.76it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  38%|███████████████▍                         | 200/532 [00:56<01:37,  3.40it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  38%|███████████████▍                         | 201/532 [00:57<01:39,  3.34it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  38%|███████████████▋                         | 204/532 [00:57<01:20,  4.07it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  39%|███████████████▊                         | 205/532 [00:58<01:27,  3.75it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  39%|███████████████▉                         | 206/532 [00:58<01:36,  3.39it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  39%|████████████████                         | 208/532 [00:58<01:24,  3.85it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  39%|████████████████▏                        | 210/532 [01:00<02:58,  1.81it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  40%|████████████████▎                        | 211/532 [01:00<02:38,  2.03it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  40%|████████████████▍                        | 213/532 [01:01<01:56,  2.74it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  40%|████████████████▍                        | 214/532 [01:01<01:51,  2.86it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  40%|████████████████▌                        | 215/532 [01:01<01:43,  3.08it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  41%|████████████████▋                        | 216/532 [01:02<01:45,  3.01it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  41%|████████████████▊                        | 218/532 [01:02<01:32,  3.41it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  41%|████████████████▉                        | 219/532 [01:03<01:35,  3.27it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  42%|█████████████████                        | 222/532 [01:03<01:18,  3.94it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  42%|█████████████████▎                       | 224/532 [01:04<01:19,  3.89it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  42%|█████████████████▎                       | 225/532 [01:04<01:27,  3.50it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  42%|█████████████████▍                       | 226/532 [01:05<01:33,  3.27it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  43%|█████████████████▌                       | 228/532 [01:05<01:22,  3.68it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  43%|█████████████████▋                       | 229/532 [01:05<01:22,  3.69it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  43%|█████████████████▋                       | 230/532 [01:06<01:26,  3.48it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  43%|█████████████████▊                       | 231/532 [01:06<01:29,  3.36it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  44%|█████████████████▉                       | 232/532 [01:06<01:33,  3.20it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  44%|█████████████████▉                       | 233/532 [01:07<01:33,  3.19it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  44%|██████████████████▏                      | 236/532 [01:07<01:13,  4.04it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  45%|██████████████████▎                      | 238/532 [01:08<01:11,  4.11it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  45%|██████████████████▌                      | 241/532 [01:09<01:06,  4.40it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  45%|██████████████████▋                      | 242/532 [01:09<01:16,  3.81it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  46%|██████████████████▊                      | 244/532 [01:09<01:09,  4.15it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  47%|███████████████████                      | 248/532 [01:10<00:59,  4.81it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  47%|███████████████████▎                     | 250/532 [01:11<01:05,  4.34it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  47%|███████████████████▍                     | 252/532 [01:11<01:05,  4.29it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  48%|███████████████████▌                     | 254/532 [01:12<01:06,  4.16it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  48%|███████████████████▋                     | 255/532 [01:12<01:11,  3.85it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  48%|███████████████████▉                     | 258/532 [01:13<01:02,  4.36it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  49%|████████████████████                     | 261/532 [01:14<01:16,  3.52it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  50%|████████████████████▎                    | 264/532 [01:15<01:03,  4.21it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  50%|████████████████████▍                    | 265/532 [01:15<01:12,  3.68it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  50%|████████████████████▌                    | 267/532 [01:15<01:08,  3.89it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  50%|████████████████████▋                    | 268/532 [01:16<01:08,  3.84it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  51%|████████████████████▋                    | 269/532 [01:16<01:10,  3.76it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  51%|████████████████████▊                    | 270/532 [01:16<01:16,  3.42it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  51%|████████████████████▉                    | 271/532 [01:17<01:20,  3.25it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  51%|█████████████████████                    | 273/532 [01:17<01:10,  3.69it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  52%|█████████████████████▍                   | 278/532 [01:18<00:52,  4.80it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  52%|█████████████████████▌                   | 279/532 [01:18<00:57,  4.40it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  53%|█████████████████████▌                   | 280/532 [01:19<01:04,  3.91it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  53%|█████████████████████▋                   | 281/532 [01:19<01:09,  3.62it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  54%|██████████████████████                   | 286/532 [01:20<00:52,  4.67it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  54%|██████████████████████                   | 287/532 [01:20<00:56,  4.31it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  54%|██████████████████████▏                  | 288/532 [01:21<01:02,  3.92it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  55%|██████████████████████▎                  | 290/532 [01:21<01:00,  3.99it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  55%|██████████████████████▍                  | 291/532 [01:22<01:03,  3.78it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  55%|██████████████████████▌                  | 292/532 [01:22<01:04,  3.69it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  55%|██████████████████████▌                  | 293/532 [01:22<01:10,  3.38it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  55%|██████████████████████▋                  | 294/532 [01:23<01:13,  3.23it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  56%|██████████████████████▉                  | 297/532 [01:23<00:58,  4.00it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  56%|██████████████████████▉                  | 298/532 [01:24<01:05,  3.58it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  56%|███████████████████████                  | 299/532 [01:24<01:09,  3.36it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  56%|███████████████████████                  | 300/532 [01:24<01:13,  3.14it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  57%|███████████████████████▌                 | 305/532 [01:25<00:50,  4.50it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  58%|███████████████████████▉                 | 311/532 [01:27<00:43,  5.10it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  59%|████████████████████████                 | 312/532 [01:27<00:53,  4.14it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  59%|████████████████████████▎                | 316/532 [01:28<00:45,  4.80it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  60%|████████████████████████▍                | 317/532 [01:28<00:49,  4.36it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  60%|████████████████████████▌                | 318/532 [01:28<00:52,  4.10it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  61%|████████████████████████▉                | 324/532 [01:30<00:41,  5.00it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  61%|█████████████████████████                | 325/532 [01:30<00:50,  4.11it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  61%|█████████████████████████                | 326/532 [01:30<00:54,  3.76it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  62%|█████████████████████████▎               | 328/532 [01:31<00:51,  3.97it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  62%|█████████████████████████▎               | 329/532 [01:31<00:52,  3.89it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  62%|█████████████████████████▍               | 330/532 [01:31<00:57,  3.51it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  62%|█████████████████████████▌               | 332/532 [01:32<00:50,  3.93it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  63%|█████████████████████████▋               | 334/532 [01:33<01:10,  2.81it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  63%|█████████████████████████▉               | 336/532 [01:33<00:58,  3.37it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  64%|██████████████████████████▎              | 342/532 [01:35<00:38,  4.91it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  65%|██████████████████████████▋              | 346/532 [01:36<00:37,  4.97it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  65%|██████████████████████████▊              | 348/532 [01:36<00:38,  4.82it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  66%|███████████████████████████              | 351/532 [01:37<00:37,  4.77it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  66%|███████████████████████████▏             | 353/532 [01:37<00:38,  4.66it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  67%|███████████████████████████▎             | 355/532 [01:38<00:39,  4.43it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  67%|███████████████████████████▌             | 357/532 [01:38<00:40,  4.30it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  68%|███████████████████████████▉             | 362/532 [01:39<00:33,  5.05it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  68%|████████████████████████████             | 364/532 [01:40<00:36,  4.59it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  69%|████████████████████████████▏            | 366/532 [01:40<00:36,  4.49it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  69%|████████████████████████████▎            | 367/532 [01:40<00:39,  4.20it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  69%|████████████████████████████▎            | 368/532 [01:41<00:42,  3.88it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  69%|████████████████████████████▍            | 369/532 [01:41<00:44,  3.68it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  70%|████████████████████████████▌            | 370/532 [01:41<00:45,  3.53it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  70%|████████████████████████████▌            | 371/532 [01:42<00:44,  3.60it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  70%|████████████████████████████▋            | 373/532 [01:43<01:29,  1.78it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  70%|████████████████████████████▊            | 374/532 [01:43<01:15,  2.10it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  71%|█████████████████████████████            | 377/532 [01:44<00:48,  3.20it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  71%|█████████████████████████████▏           | 378/532 [01:44<00:48,  3.19it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  72%|█████████████████████████████▎           | 381/532 [01:45<00:38,  3.94it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  72%|█████████████████████████████▍           | 382/532 [01:45<00:38,  3.88it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  72%|█████████████████████████████▌           | 383/532 [01:46<00:40,  3.67it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  72%|█████████████████████████████▌           | 384/532 [01:46<00:42,  3.52it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  73%|█████████████████████████████▋           | 386/532 [01:47<00:38,  3.81it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  73%|█████████████████████████████▊           | 387/532 [01:47<00:40,  3.58it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  73%|█████████████████████████████▉           | 389/532 [01:47<00:36,  3.91it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  74%|██████████████████████████████▎          | 394/532 [01:48<00:29,  4.66it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  74%|██████████████████████████████▍          | 395/532 [01:49<00:33,  4.07it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  75%|██████████████████████████████▌          | 397/532 [01:49<00:33,  4.06it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  75%|██████████████████████████████▋          | 398/532 [01:50<00:34,  3.86it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  75%|██████████████████████████████▉          | 401/532 [01:50<00:31,  4.22it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  76%|███████████████████████████████          | 403/532 [01:51<00:30,  4.20it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  76%|███████████████████████████████▏         | 405/532 [01:51<00:29,  4.25it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  76%|███████████████████████████████▎         | 406/532 [01:52<00:33,  3.80it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  77%|███████████████████████████████▍         | 408/532 [01:52<00:32,  3.86it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  77%|███████████████████████████████▋         | 411/532 [01:53<00:28,  4.32it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  77%|███████████████████████████████▊         | 412/532 [01:53<00:30,  3.92it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  78%|███████████████████████████████▊         | 413/532 [01:53<00:31,  3.81it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  78%|███████████████████████████████▉         | 414/532 [01:54<00:32,  3.60it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  78%|████████████████████████████████         | 416/532 [01:54<00:30,  3.78it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  79%|████████████████████████████████▎        | 420/532 [01:55<00:24,  4.52it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  79%|████████████████████████████████▍        | 421/532 [01:56<00:28,  3.84it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  80%|████████████████████████████████▌        | 423/532 [01:56<00:27,  3.98it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  80%|████████████████████████████████▊        | 426/532 [01:57<00:39,  2.69it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  80%|████████████████████████████████▉        | 427/532 [01:58<00:38,  2.73it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  81%|█████████████████████████████████▏       | 430/532 [01:58<00:27,  3.76it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  81%|█████████████████████████████████▏       | 431/532 [01:59<00:27,  3.73it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  81%|█████████████████████████████████▎       | 432/532 [01:59<00:27,  3.60it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  81%|█████████████████████████████████▎       | 433/532 [01:59<00:28,  3.48it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  82%|█████████████████████████████████▍       | 434/532 [02:00<00:30,  3.26it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  82%|█████████████████████████████████▌       | 435/532 [02:00<00:29,  3.24it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  82%|█████████████████████████████████▋       | 437/532 [02:01<00:26,  3.61it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  83%|█████████████████████████████████▉       | 440/532 [02:01<00:22,  4.07it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  83%|██████████████████████████████████       | 442/532 [02:02<00:21,  4.12it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  83%|██████████████████████████████████▏      | 444/532 [02:02<00:20,  4.21it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  84%|██████████████████████████████████▍      | 447/532 [02:03<00:19,  4.45it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  84%|██████████████████████████████████▌      | 448/532 [02:03<00:21,  3.97it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  85%|██████████████████████████████████▋      | 450/532 [02:04<00:20,  4.09it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  85%|██████████████████████████████████▊      | 452/532 [02:04<00:18,  4.23it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  85%|██████████████████████████████████▉      | 454/532 [02:05<00:18,  4.23it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  86%|███████████████████████████████████▏     | 456/532 [02:05<00:18,  4.20it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  86%|███████████████████████████████████▏     | 457/532 [02:06<00:19,  3.83it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  86%|███████████████████████████████████▎     | 459/532 [02:06<00:18,  4.02it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  87%|███████████████████████████████████▌     | 461/532 [02:07<00:17,  4.10it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  87%|███████████████████████████████████▌     | 462/532 [02:07<00:19,  3.64it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  87%|███████████████████████████████████▊     | 465/532 [02:08<00:15,  4.25it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  88%|████████████████████████████████████▏    | 470/532 [02:09<00:12,  4.98it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  89%|████████████████████████████████████▎    | 471/532 [02:09<00:14,  4.34it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  89%|████████████████████████████████████▍    | 472/532 [02:09<00:15,  3.96it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  89%|████████████████████████████████████▍    | 473/532 [02:10<00:16,  3.56it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  89%|████████████████████████████████████▌    | 474/532 [02:10<00:16,  3.48it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  89%|████████████████████████████████████▌    | 475/532 [02:10<00:16,  3.40it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  89%|████████████████████████████████████▋    | 476/532 [02:10<00:17,  3.20it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  90%|████████████████████████████████████▊    | 477/532 [02:11<00:17,  3.12it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  90%|████████████████████████████████████▊    | 478/532 [02:11<00:17,  3.15it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  90%|████████████████████████████████████▉    | 480/532 [02:12<00:13,  3.72it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  90%|█████████████████████████████████████    | 481/532 [02:12<00:14,  3.44it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  91%|█████████████████████████████████████▏   | 482/532 [02:12<00:14,  3.39it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  91%|█████████████████████████████████████▎   | 484/532 [02:13<00:12,  3.73it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  91%|█████████████████████████████████████▍   | 486/532 [02:14<00:25,  1.84it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  92%|█████████████████████████████████████▌   | 488/532 [02:15<00:17,  2.58it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  92%|█████████████████████████████████████▊   | 490/532 [02:15<00:13,  3.12it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  92%|█████████████████████████████████████▉   | 492/532 [02:16<00:11,  3.51it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  93%|█████████████████████████████████████▉   | 493/532 [02:16<00:10,  3.57it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  93%|██████████████████████████████████████   | 494/532 [02:16<00:11,  3.43it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  93%|██████████████████████████████████████▏  | 496/532 [02:17<00:09,  3.86it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  93%|██████████████████████████████████████▎  | 497/532 [02:17<00:09,  3.51it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  94%|██████████████████████████████████████▍  | 499/532 [02:18<00:08,  3.77it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  94%|██████████████████████████████████████▌  | 500/532 [02:18<00:09,  3.46it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  95%|██████████████████████████████████████▊  | 504/532 [02:20<00:14,  1.90it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  95%|██████████████████████████████████████▉  | 505/532 [02:20<00:12,  2.17it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  95%|███████████████████████████████████████▏ | 508/532 [02:21<00:07,  3.19it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  96%|███████████████████████████████████████▍ | 511/532 [02:22<00:05,  4.03it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  96%|███████████████████████████████████████▍ | 512/532 [02:22<00:05,  3.93it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  96%|███████████████████████████████████████▌ | 513/532 [02:22<00:05,  3.67it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  97%|███████████████████████████████████████▌ | 514/532 [02:23<00:05,  3.51it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  97%|███████████████████████████████████████▋ | 515/532 [02:23<00:04,  3.53it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  97%|███████████████████████████████████████▊ | 516/532 [02:23<00:04,  3.50it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  98%|███████████████████████████████████████▉ | 519/532 [02:24<00:03,  4.13it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  98%|████████████████████████████████████████ | 520/532 [02:24<00:03,  3.58it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  98%|████████████████████████████████████████▏| 521/532 [02:25<00:03,  3.46it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  98%|████████████████████████████████████████▎| 523/532 [02:25<00:02,  3.73it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  98%|████████████████████████████████████████▍| 524/532 [02:25<00:02,  3.43it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#  99%|████████████████████████████████████████▌| 527/532 [02:26<00:01,  4.14it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|████████████████████████████████████████▊| 530/532 [02:27<00:00,  4.26it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|████████████████████████████████████████▉| 531/532 [02:27<00:00,  3.83it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|█████████████████████████████████████████| 532/532 [02:27<00:00,  3.60it/s]

# %%
tri.description
# Out:
# {'vertices': [{'mark': 'A', 'x': 0.33, 'y': 0.0},
#   {'mark': 'B', 'x': 1.0, 'y': 1.0},
#   {'mark': 'C', 'x': 0.0, 'y': 0.37}],
#  'segments': [{'mark': 'AB', 'known': True, 'length': 14.0, 'unit': 'cm'},
#   {'mark': 'AC', 'known': False},
#   {'mark': 'BC', 'known': True, 'length': 15.23, 'unit': 'cm'}],
#  'angles': [{'mark': 'ABC', 'known': False},
#   {'mark': 'BCA', 'known': False},
#   {'mark': 'CAB', 'known': True, 'value': 90, 'unit': 'deg'}],
#  'specials': [],
#  'questions': ['Find Segment AC. ', 'Find Angle ∢ABC. '],
#  'index_lookup': {'A': 0, 'B': 1, 'C': 2}}
